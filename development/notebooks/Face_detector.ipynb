# %% [markdown]
# # Importar librerías

# %%
import cv2
from pathlib import Path
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Pruebas con imagenes

# %%
PATH = Path('/home/javier/Escritorio/archive/')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

# %%
#im = Image.open(PATH/'images/maksssksksss8.png')
im = Image.open(PATH/'faces.jpeg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x7FA18019BB80>

# %%
np_im = np.asarray(im)

# %%
#gray = cv2.cvtColor(cv2.UMat(np_im), cv2.COLOR_BGR2GRAY)
gray = cv2.cvtColor(np_im, cv2.COLOR_RGB2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.1, 1)

# %%
faces
# Out:
# array([[412,  44, 129, 129],
#        [832,  66, 138, 138],
#        [691, 100, 111, 111],
#        [588, 174, 114, 114],
#        [781, 212, 139, 139],
#        [155, 136, 109, 109],
#        [228, 126, 142, 142],
#        [199, 265, 158, 158],
#        [443, 232, 165, 165],
#        [  0, 299, 127, 127],
#        [596, 301, 166, 166]], dtype=int32)

# %%
#img = ImageDraw.Draw(im)
for (x, y, w, h) in faces:
    #img.rectangle([(x, y), (w, h)], outline = "white")
    cv2.rectangle(np_im, (x, y), (x+w, y+h), (255, 255, 255), 2)

# %%
cap = cv2.VideoCapture(0)
_, frame = cap.read()
gray_camera = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
cap.release()

# %%
cv2.imshow('gray',np_im[...,[2,1,0]]) #BGR to RGB
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray
# Out:
# array([[230, 245, 249, ..., 249, 247, 245],
#        [230, 244, 249, ..., 250, 250, 248],
#        [229, 244, 249, ..., 251, 251, 250],
#        ...,
#        [148, 144, 144, ..., 140, 136, 139],
#        [149, 159, 151, ..., 140, 137, 141],
#        [152, 159, 171, ..., 139, 137, 142]], dtype=uint8)

# %%
print(len(gray))
print(len(gray_camera))
# Out:
# 366
# 480

# %% [markdown]
# # Pruebas cámara

# %%
import cv2

face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

cap = cv2.VideoCapture(0)

while True:
    
    _, frame = cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 255, 255), 2)
        
    cv2.imshow('img', frame)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()
